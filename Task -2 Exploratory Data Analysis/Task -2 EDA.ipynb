# %% [markdown]
# ![Innomatics-Research-Labs-Logo.svg](attachment:Innomatics-Research-Labs-Logo.svg)

# %%
# Importing the required Libraries
import numpy as np
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import datetime

from statsmodels.graphics.gofplots import qqplot
from scipy.stats import boxcox
from scipy.stats import norm

from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings("ignore")

plt.style.use("fivethirtyeight")

# %%
# Loading the DataFrame
pd.set_option("display.max_columns",100)
df = pd.read_excel("aspiring_minds_employability_outcomes_2015.xlsx",engine="openpyxl")

# %%
# Checking the head of the Data
df.head()
# Out:
#   Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0      train  203097   420000 2012-06-01              present
# 1      train  579905   500000 2013-09-01              present
# 2      train  810601   325000 2014-06-01              present
# 3      train  267447  1100000 2011-07-01              present
# 4      train  343523   200000 2014-03-01  2015-03-01 00:00:00
#
#                 Designation    JobCity Gender        DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f 1990-02-19          84.3
# 1         assistant manager     Indore      m 1989-10-04          85.4
# 2          systems engineer    Chennai      f 1992-08-03          85.0
# 3  senior software engineer    Gurgaon      m 1989-12-05          85.6
# 4                       get    Manesar      m 1991-02-27          78.0
#
#                           10board  12graduation  12percentage  \
# 0  board ofsecondary education,ap          2007          95.8
# 1                            cbse          2007          85.0
# 2                            cbse          2010          68.2
# 3                            cbse          2007          83.6
# 4                            cbse          2008          76.8
#
#                               12board  CollegeID  CollegeTier       Degree  \
# 0  board of intermediate education,ap       1141            2  B.Tech/B.E.
# 1                                cbse       5807            2  B.Tech/B.E.
# 2                                cbse         64            2  B.Tech/B.E.
# 3                                cbse       6920            1  B.Tech/B.E.
# 4                                cbse      11368            2  B.Tech/B.E.
#
#                               Specialization  collegeGPA  CollegeCityID  \
# 0                       computer engineering       78.00           1141
# 1  electronics and communication engineering       70.06           5807
# 2                     information technology       70.00             64
# 3                       computer engineering       74.64           6920
# 4  electronics and communication engineering       73.90          11368
#
#    CollegeCityTier    CollegeState  GraduationYear  English  Logical  Quant  \
# 0                0  Andhra Pradesh            2011      515      585    525
# 1                0  Madhya Pradesh            2012      695      610    780
# 2                0   Uttar Pradesh            2014      615      545    370
# 3                1           Delhi            2011      635      585    625
# 4                0   Uttar Pradesh            2012      545      625    465
#
#      Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  \
# 0  0.635979                  445                     -1               -1
# 1  0.960603                   -1                    466               -1
# 2  0.450877                  395                     -1               -1
# 3  0.974396                  615                     -1               -1
# 4  0.124502                   -1                    233               -1
#
#    MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  conscientiousness  \
# 0              -1              -1           -1         -1             0.9737
# 1              -1              -1           -1         -1            -0.7335
# 2              -1              -1           -1         -1             0.2718
# 3              -1              -1           -1         -1             0.0464
# 4              -1              -1           -1         -1            -0.8810
#
#    agreeableness  extraversion  nueroticism  openess_to_experience
# 0         0.8128        0.5269      1.35490                -0.4455
# 1         0.3789        1.2396     -0.10760                 0.8637
# 2         1.7109        0.1637     -0.86820                 0.6721
# 3         0.3448       -0.3440     -0.40780                -0.9194
# 4        -0.2793       -1.0697      0.09163                -0.1295

# %%
# After seeing the data head , the Unnamed: 0 column seems suspicious for me, so checking the values in it
df['Unnamed: 0'].value_counts()
# Out:
# train    3998
# Name: Unnamed: 0, dtype: int64

# %%
# Dropping the Unnamed: 0 column because it contains only one value
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
# Checking the ID column
df['ID'].nunique()
# Out:
# 3998

# %%
# Dropping The ID Column
df.drop("ID",axis=1,inplace=True)

# %%
# Checking the Shape of the DataFrame
df.shape
# Out:
# (3998, 37)

# %%
# Checking the basic Description of the DataFrame
df.describe()
# Out:
#              Salary  10percentage  12graduation  12percentage     CollegeID  \
# count  3.998000e+03   3998.000000   3998.000000   3998.000000   3998.000000
# mean   3.076998e+05     77.925443   2008.087544     74.466366   5156.851426
# std    2.127375e+05      9.850162      1.653599     10.999933   4802.261482
# min    3.500000e+04     43.000000   1995.000000     40.000000      2.000000
# 25%    1.800000e+05     71.680000   2007.000000     66.000000    494.000000
# 50%    3.000000e+05     79.150000   2008.000000     74.400000   3879.000000
# 75%    3.700000e+05     85.670000   2009.000000     82.600000   8818.000000
# max    4.000000e+06     97.760000   2013.000000     98.700000  18409.000000
#
#        CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count  3998.000000  3998.000000    3998.000000      3998.000000
# mean      1.925713    71.486171    5156.851426         0.300400
# std       0.262270     8.167338    4802.261482         0.458489
# min       1.000000     6.450000       2.000000         0.000000
# 25%       2.000000    66.407500     494.000000         0.000000
# 50%       2.000000    71.720000    3879.000000         0.000000
# 75%       2.000000    76.327500    8818.000000         1.000000
# max       2.000000    99.930000   18409.000000         1.000000
#
#        GraduationYear      English      Logical        Quant       Domain  \
# count     3998.000000  3998.000000  3998.000000  3998.000000  3998.000000
# mean      2012.105803   501.649075   501.598799   513.378189     0.510490
# std         31.857271   104.940021    86.783297   122.302332     0.468671
# min          0.000000   180.000000   195.000000   120.000000    -1.000000
# 25%       2012.000000   425.000000   445.000000   430.000000     0.342315
# 50%       2013.000000   500.000000   505.000000   515.000000     0.622643
# 75%       2014.000000   570.000000   565.000000   595.000000     0.842248
# max       2017.000000   875.000000   795.000000   900.000000     0.999910
#
#        ComputerProgramming  ElectronicsAndSemicon  ComputerScience  \
# count          3998.000000            3998.000000      3998.000000
# mean            353.102801              95.328414        90.742371
# std             205.355519             158.241218       175.273083
# min              -1.000000              -1.000000        -1.000000
# 25%             295.000000              -1.000000        -1.000000
# 50%             415.000000              -1.000000        -1.000000
# 75%             495.000000             233.000000        -1.000000
# max             840.000000             612.000000       715.000000
#
#        MechanicalEngg  ElectricalEngg  TelecomEngg    CivilEngg  \
# count     3998.000000     3998.000000  3998.000000  3998.000000
# mean        22.974737       16.478739    31.851176     2.683842
# std         98.123311       87.585634   104.852845    36.658505
# min         -1.000000       -1.000000    -1.000000    -1.000000
# 25%         -1.000000       -1.000000    -1.000000    -1.000000
# 50%         -1.000000       -1.000000    -1.000000    -1.000000
# 75%         -1.000000       -1.000000    -1.000000    -1.000000
# max        623.000000      676.000000   548.000000   516.000000
#
#        conscientiousness  agreeableness  extraversion  nueroticism  \
# count        3998.000000    3998.000000   3998.000000  3998.000000
# mean           -0.037831       0.146496      0.002763    -0.169033
# std             1.028666       0.941782      0.951471     1.007580
# min            -4.126700      -5.781600     -4.600900    -2.643000
# 25%            -0.713525      -0.287100     -0.604800    -0.868200
# 50%             0.046400       0.212400      0.091400    -0.234400
# 75%             0.702700       0.812800      0.672000     0.526200
# max             1.995300       1.904800      2.535400     3.352500
#
#        openess_to_experience
# count            3998.000000
# mean               -0.138110
# std                 1.008075
# min                -7.375700
# 25%                -0.669200
# 50%                -0.094300
# 75%                 0.502400
# max                 1.822400

# %%
# Checking the Basic info of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Salary                 3998 non-null   int64
#  1   DOJ                    3998 non-null   datetime64[ns]
#  2   DOL                    3998 non-null   object
#  3   Designation            3998 non-null   object
#  4   JobCity                3998 non-null   object
#  5   Gender                 3998 non-null   object
#  6   DOB                    3998 non-null   datetime64[ns]
#  7   10percentage           3998 non-null   float64
#  8   10board                3998 non-null   object
#  9   12graduation           3998 non-null   int64
#  10  12percentage           3998 non-null   float64
#  11  12board                3998 non-null   object
#  12  CollegeID              3998 non-null   int64
#  13  CollegeTier            3998 non-null   int64
#  14  Degree                 3998 non-null   object
#  15  Specialization         3998 non-null   object
#  16  collegeGPA             3998 non-null   float64
#  17  CollegeCityID          3998 non-null   int64
#  18  CollegeCityTier        3998 non-null   int64
#  19  CollegeState           3998 non-null   object
#  20  GraduationYear         3998 non-null   int64
#  21  English                3998 non-null   int64
#  22  Logical                3998 non-null   int64
#  23  Quant                  3998 non-null   int64
#  24  Domain                 3998 non-null   float64
#  25  ComputerProgramming    3998 non-null   int64
#  26  ElectronicsAndSemicon  3998 non-null   int64
#  27  ComputerScience        3998 non-null   int64
#  28  MechanicalEngg         3998 non-null   int64
#  29  ElectricalEngg         3998 non-null   int64
#  30  TelecomEngg            3998 non-null   int64
#  31  CivilEngg              3998 non-null   int64
#  32  conscientiousness      3998 non-null   float64
#  33  agreeableness          3998 non-null   float64
#  34  extraversion           3998 non-null   float64
#  35  nueroticism            3998 non-null   float64
#  36  openess_to_experience  3998 non-null   float64
# dtypes: datetime64[ns](2), float64(9), int64(17), object(9)
# memory usage: 1.1+ MB

# %%
# Checking for the NULL values in the DataFrame
df.isnull().sum()
# Out:
# Salary                   0
# DOJ                      0
# DOL                      0
# Designation              0
# JobCity                  0
# Gender                   0
# DOB                      0
# 10percentage             0
# 10board                  0
# 12graduation             0
# 12percentage             0
# 12board                  0
# CollegeID                0
# CollegeTier              0
# Degree                   0
# Specialization           0
# collegeGPA               0
# CollegeCityID            0
# CollegeCityTier          0
# CollegeState             0
# GraduationYear           0
# English                  0
# Logical                  0
# Quant                    0
# Domain                   0
# ComputerProgramming      0
# ElectronicsAndSemicon    0
# ComputerScience          0
# MechanicalEngg           0
# ElectricalEngg           0
# TelecomEngg              0
# CivilEngg                0
# conscientiousness        0
# agreeableness            0
# extraversion             0
# nueroticism              0
# openess_to_experience    0
# dtype: int64

# %%
# Extracting the Numerical_columns from the total columns
numerical_columns = [column for column in df.columns if column not in df.select_dtypes(include="O")]

# %%
df[numerical_columns]
# Out:
#        Salary        DOJ        DOB  10percentage  12graduation  12percentage  \
# 0      420000 2012-06-01 1990-02-19         84.30          2007         95.80
# 1      500000 2013-09-01 1989-10-04         85.40          2007         85.00
# 2      325000 2014-06-01 1992-08-03         85.00          2010         68.20
# 3     1100000 2011-07-01 1989-12-05         85.60          2007         83.60
# 4      200000 2014-03-01 1991-02-27         78.00          2008         76.80
# ...       ...        ...        ...           ...           ...           ...
# 3993   280000 2011-10-01 1987-04-15         52.09          2006         55.50
# 3994   100000 2013-07-01 1992-08-27         90.00          2009         93.00
# 3995   320000 2013-07-01 1991-07-03         81.86          2008         65.50
# 3996   200000 2014-07-01 1992-03-20         78.72          2010         69.88
# 3997   400000 2013-02-01 1991-02-26         70.60          2008         68.00
#
#       CollegeID  CollegeTier  collegeGPA  CollegeCityID  CollegeCityTier  \
# 0          1141            2       78.00           1141                0
# 1          5807            2       70.06           5807                0
# 2            64            2       70.00             64                0
# 3          6920            1       74.64           6920                1
# 4         11368            2       73.90          11368                0
# ...         ...          ...         ...            ...              ...
# 3993       6268            2       61.50           6268                0
# 3994       4883            2       77.30           4883                1
# 3995       9786            2       70.00           9786                0
# 3996        979            2       70.42            979                1
# 3997       6609            2       68.00           6609                1
#
#       GraduationYear  English  Logical  Quant    Domain  ComputerProgramming  \
# 0               2011      515      585    525  0.635979                  445
# 1               2012      695      610    780  0.960603                   -1
# 2               2014      615      545    370  0.450877                  395
# 3               2011      635      585    625  0.974396                  615
# 4               2012      545      625    465  0.124502                   -1
# ...              ...      ...      ...    ...       ...                  ...
# 3993            2010      365      334    475  0.276047                  345
# 3994            2013      415      410    535  0.881620                  325
# 3995            2012      475      475    465  0.488348                  405
# 3996            2014      450      410    320  0.744758                  445
# 3997            2012      565      515    464  0.600057                  435
#
#       ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  \
# 0                        -1               -1              -1              -1
# 1                       466               -1              -1              -1
# 2                        -1               -1              -1              -1
# 3                        -1               -1              -1              -1
# 4                       233               -1              -1              -1
# ...                     ...              ...             ...             ...
# 3993                     -1               -1              -1              -1
# 3994                    420               -1              -1              -1
# 3995                     -1               -1              -1              -1
# 3996                     -1              438              -1              -1
# 3997                     -1               -1              -1              -1
#
#       TelecomEngg  CivilEngg  conscientiousness  agreeableness  extraversion  \
# 0              -1         -1             0.9737         0.8128        0.5269
# 1              -1         -1            -0.7335         0.3789        1.2396
# 2              -1         -1             0.2718         1.7109        0.1637
# 3              -1         -1             0.0464         0.3448       -0.3440
# 4              -1         -1            -0.8810        -0.2793       -1.0697
# ...           ...        ...                ...            ...           ...
# 3993           -1         -1            -0.1082         0.3448        0.2366
# 3994           -1         -1            -0.3027         0.8784        0.9322
# 3995           -1         -1            -1.5765        -1.5273       -1.5051
# 3996           -1         -1            -0.1590         0.0459       -0.4511
# 3997           -1         -1            -1.1128        -0.2793       -0.6343
#
#       nueroticism  openess_to_experience
# 0         1.35490                -0.4455
# 1        -0.10760                 0.8637
# 2        -0.86820                 0.6721
# 3        -0.40780                -0.9194
# 4         0.09163                -0.1295
# ...           ...                    ...
# 3993      0.64980                -0.9194
# 3994      0.77980                -0.0943
# 3995     -1.31840                -0.7615
# 3996     -0.36120                -0.0943
# 3997      1.32553                -0.6035
#
# [3998 rows x 28 columns]

# %%
numerical_discrete_columns = [column for column in numerical_columns if df[column].nunique() < 25]

# %%
df[numerical_discrete_columns]
# Out:
#       12graduation  CollegeTier  CollegeCityTier  GraduationYear  \
# 0             2007            2                0            2011
# 1             2007            2                0            2012
# 2             2010            2                0            2014
# 3             2007            1                1            2011
# 4             2008            2                0            2012
# ...            ...          ...              ...             ...
# 3993          2006            2                0            2010
# 3994          2009            2                1            2013
# 3995          2008            2                0            2012
# 3996          2010            2                1            2014
# 3997          2008            2                1            2012
#
#       ComputerScience  CivilEngg
# 0                  -1         -1
# 1                  -1         -1
# 2                  -1         -1
# 3                  -1         -1
# 4                  -1         -1
# ...               ...        ...
# 3993               -1         -1
# 3994               -1         -1
# 3995               -1         -1
# 3996              438         -1
# 3997               -1         -1
#
# [3998 rows x 6 columns]

# %%
numerical_columns = [column for column in numerical_columns if column not in numerical_discrete_columns]

# %%
df[numerical_columns]
# Out:
#        Salary        DOJ        DOB  10percentage  12percentage  CollegeID  \
# 0      420000 2012-06-01 1990-02-19         84.30         95.80       1141
# 1      500000 2013-09-01 1989-10-04         85.40         85.00       5807
# 2      325000 2014-06-01 1992-08-03         85.00         68.20         64
# 3     1100000 2011-07-01 1989-12-05         85.60         83.60       6920
# 4      200000 2014-03-01 1991-02-27         78.00         76.80      11368
# ...       ...        ...        ...           ...           ...        ...
# 3993   280000 2011-10-01 1987-04-15         52.09         55.50       6268
# 3994   100000 2013-07-01 1992-08-27         90.00         93.00       4883
# 3995   320000 2013-07-01 1991-07-03         81.86         65.50       9786
# 3996   200000 2014-07-01 1992-03-20         78.72         69.88        979
# 3997   400000 2013-02-01 1991-02-26         70.60         68.00       6609
#
#       collegeGPA  CollegeCityID  English  Logical  Quant    Domain  \
# 0          78.00           1141      515      585    525  0.635979
# 1          70.06           5807      695      610    780  0.960603
# 2          70.00             64      615      545    370  0.450877
# 3          74.64           6920      635      585    625  0.974396
# 4          73.90          11368      545      625    465  0.124502
# ...          ...            ...      ...      ...    ...       ...
# 3993       61.50           6268      365      334    475  0.276047
# 3994       77.30           4883      415      410    535  0.881620
# 3995       70.00           9786      475      475    465  0.488348
# 3996       70.42            979      450      410    320  0.744758
# 3997       68.00           6609      565      515    464  0.600057
#
#       ComputerProgramming  ElectronicsAndSemicon  MechanicalEngg  \
# 0                     445                     -1              -1
# 1                      -1                    466              -1
# 2                     395                     -1              -1
# 3                     615                     -1              -1
# 4                      -1                    233              -1
# ...                   ...                    ...             ...
# 3993                  345                     -1              -1
# 3994                  325                    420              -1
# 3995                  405                     -1              -1
# 3996                  445                     -1              -1
# 3997                  435                     -1              -1
#
#       ElectricalEngg  TelecomEngg  conscientiousness  agreeableness  \
# 0                 -1           -1             0.9737         0.8128
# 1                 -1           -1            -0.7335         0.3789
# 2                 -1           -1             0.2718         1.7109
# 3                 -1           -1             0.0464         0.3448
# 4                 -1           -1            -0.8810        -0.2793
# ...              ...          ...                ...            ...
# 3993              -1           -1            -0.1082         0.3448
# 3994              -1           -1            -0.3027         0.8784
# 3995              -1           -1            -1.5765        -1.5273
# 3996              -1           -1            -0.1590         0.0459
# 3997              -1           -1            -1.1128        -0.2793
#
#       extraversion  nueroticism  openess_to_experience
# 0           0.5269      1.35490                -0.4455
# 1           1.2396     -0.10760                 0.8637
# 2           0.1637     -0.86820                 0.6721
# 3          -0.3440     -0.40780                -0.9194
# 4          -1.0697      0.09163                -0.1295
# ...            ...          ...                    ...
# 3993        0.2366      0.64980                -0.9194
# 3994        0.9322      0.77980                -0.0943
# 3995       -1.5051     -1.31840                -0.7615
# 3996       -0.4511     -0.36120                -0.0943
# 3997       -0.6343      1.32553                -0.6035
#
# [3998 rows x 22 columns]

# %%
df[numerical_discrete_columns].nunique()
# Out:
# 12graduation       16
# CollegeTier         2
# CollegeCityTier     2
# GraduationYear     11
# ComputerScience    20
# CivilEngg          23
# dtype: int64

# %%
# Looking at the numerical columns
df[numerical_columns].nunique()
# Out:
# Salary                    177
# DOJ                        81
# DOB                      1872
# 10percentage              851
# 12percentage              801
# CollegeID                1350
# collegeGPA               1282
# CollegeCityID            1350
# English                   111
# Logical                   107
# Quant                     138
# Domain                    243
# ComputerProgramming        79
# ElectronicsAndSemicon      29
# MechanicalEngg             42
# ElectricalEngg             31
# TelecomEngg                26
# conscientiousness         141
# agreeableness             149
# extraversion              154
# nueroticism               217
# openess_to_experience     142
# dtype: int64

# %%
date_columns = ['DOJ',"DOL","DOB"]

# %%
present_year = datetime.datetime.now()

# %%
df["DOL"].replace("present",present_year,inplace=True)

# %%
df[date_columns].dtypes
# Out:
# DOJ    datetime64[ns]
# DOL    datetime64[ns]
# DOB    datetime64[ns]
# dtype: object

# %%
# Removing Datetime columns from Numerical columns:
numerical_columns = [column for column in numerical_columns if column not in date_columns]

# %%
df[numerical_columns]
# Out:
#        Salary  10percentage  12percentage  CollegeID  collegeGPA  \
# 0      420000         84.30         95.80       1141       78.00
# 1      500000         85.40         85.00       5807       70.06
# 2      325000         85.00         68.20         64       70.00
# 3     1100000         85.60         83.60       6920       74.64
# 4      200000         78.00         76.80      11368       73.90
# ...       ...           ...           ...        ...         ...
# 3993   280000         52.09         55.50       6268       61.50
# 3994   100000         90.00         93.00       4883       77.30
# 3995   320000         81.86         65.50       9786       70.00
# 3996   200000         78.72         69.88        979       70.42
# 3997   400000         70.60         68.00       6609       68.00
#
#       CollegeCityID  English  Logical  Quant    Domain  ComputerProgramming  \
# 0              1141      515      585    525  0.635979                  445
# 1              5807      695      610    780  0.960603                   -1
# 2                64      615      545    370  0.450877                  395
# 3              6920      635      585    625  0.974396                  615
# 4             11368      545      625    465  0.124502                   -1
# ...             ...      ...      ...    ...       ...                  ...
# 3993           6268      365      334    475  0.276047                  345
# 3994           4883      415      410    535  0.881620                  325
# 3995           9786      475      475    465  0.488348                  405
# 3996            979      450      410    320  0.744758                  445
# 3997           6609      565      515    464  0.600057                  435
#
#       ElectronicsAndSemicon  MechanicalEngg  ElectricalEngg  TelecomEngg  \
# 0                        -1              -1              -1           -1
# 1                       466              -1              -1           -1
# 2                        -1              -1              -1           -1
# 3                        -1              -1              -1           -1
# 4                       233              -1              -1           -1
# ...                     ...             ...             ...          ...
# 3993                     -1              -1              -1           -1
# 3994                    420              -1              -1           -1
# 3995                     -1              -1              -1           -1
# 3996                     -1              -1              -1           -1
# 3997                     -1              -1              -1           -1
#
#       conscientiousness  agreeableness  extraversion  nueroticism  \
# 0                0.9737         0.8128        0.5269      1.35490
# 1               -0.7335         0.3789        1.2396     -0.10760
# 2                0.2718         1.7109        0.1637     -0.86820
# 3                0.0464         0.3448       -0.3440     -0.40780
# 4               -0.8810        -0.2793       -1.0697      0.09163
# ...                 ...            ...           ...          ...
# 3993            -0.1082         0.3448        0.2366      0.64980
# 3994            -0.3027         0.8784        0.9322      0.77980
# 3995            -1.5765        -1.5273       -1.5051     -1.31840
# 3996            -0.1590         0.0459       -0.4511     -0.36120
# 3997            -1.1128        -0.2793       -0.6343      1.32553
#
#       openess_to_experience
# 0                   -0.4455
# 1                    0.8637
# 2                    0.6721
# 3                   -0.9194
# 4                   -0.1295
# ...                     ...
# 3993                -0.9194
# 3994                -0.0943
# 3995                -0.7615
# 3996                -0.0943
# 3997                -0.6035
#
# [3998 rows x 20 columns]

# %%
# Extracting the Categorical Columns
categorical_columns = [column for column in df.columns if column in df.select_dtypes(include="O")]

# %%
# Looking at the categorical columns
df[categorical_columns]
# Out:
#                       Designation           JobCity Gender  \
# 0         senior quality engineer         Bangalore      f
# 1               assistant manager            Indore      m
# 2                systems engineer           Chennai      f
# 3        senior software engineer           Gurgaon      m
# 4                             get           Manesar      m
# ...                           ...               ...    ...
# 3993            software engineer        New Delhi       m
# 3994             technical writer         Hyderabad      f
# 3995  associate software engineer         Bangalore      m
# 3996           software developer  Asifabadbanglore      f
# 3997      senior systems engineer           Chennai      f
#
#                              10board                             12board  \
# 0     board ofsecondary education,ap  board of intermediate education,ap
# 1                               cbse                                cbse
# 2                               cbse                                cbse
# 3                               cbse                                cbse
# 4                               cbse                                cbse
# ...                              ...                                 ...
# 3993                            cbse                                cbse
# 3994                     state board                         state board
# 3995                      bse,odisha                         chse,odisha
# 3996                     state board                         state board
# 3997                            cbse                                cbse
#
#            Degree                             Specialization    CollegeState
# 0     B.Tech/B.E.                       computer engineering  Andhra Pradesh
# 1     B.Tech/B.E.  electronics and communication engineering  Madhya Pradesh
# 2     B.Tech/B.E.                     information technology   Uttar Pradesh
# 3     B.Tech/B.E.                       computer engineering           Delhi
# 4     B.Tech/B.E.  electronics and communication engineering   Uttar Pradesh
# ...           ...                                        ...             ...
# 3993  B.Tech/B.E.                     information technology         Haryana
# 3994  B.Tech/B.E.  electronics and communication engineering       Telangana
# 3995  B.Tech/B.E.                       computer engineering          Orissa
# 3996  B.Tech/B.E.             computer science & engineering       Karnataka
# 3997  B.Tech/B.E.                     information technology      Tamil Nadu
#
# [3998 rows x 8 columns]

# %%
categorical_discrete_columns = [column for column in categorical_columns if df[column].nunique() < 25]

# %%
df[categorical_discrete_columns].nunique()
# Out:
# Gender    2
# Degree    4
# dtype: int64

# %%
# Building a fuction which will give the number of unique values
def unique_values(df,columns):
    values = []
    for column in columns:
        nunique = df[column].nunique()
        values.append(nunique)
    unique_df = pd.DataFrame({"Columns":columns,"No.of Unique Values":values})
    return unique_df

# %%
unique_values(df,numerical_columns)
# Out:
#                   Columns  No.of Unique Values
# 0                  Salary                  177
# 1            10percentage                  851
# 2            12percentage                  801
# 3               CollegeID                 1350
# 4              collegeGPA                 1282
# 5           CollegeCityID                 1350
# 6                 English                  111
# 7                 Logical                  107
# 8                   Quant                  138
# 9                  Domain                  243
# 10    ComputerProgramming                   79
# 11  ElectronicsAndSemicon                   29
# 12         MechanicalEngg                   42
# 13         ElectricalEngg                   31
# 14            TelecomEngg                   26
# 15      conscientiousness                  141
# 16          agreeableness                  149
# 17           extraversion                  154
# 18            nueroticism                  217
# 19  openess_to_experience                  142

# %%
unique_values(df,numerical_discrete_columns)
# Out:
#            Columns  No.of Unique Values
# 0     12graduation                   16
# 1      CollegeTier                    2
# 2  CollegeCityTier                    2
# 3   GraduationYear                   11
# 4  ComputerScience                   20
# 5        CivilEngg                   23

# %%
# Confirming that whether they are categorical columns or not
sns.countplot(df['CollegeTier'],palette="coolwarm")
plt.title("Frquency of CollegeTier")
# Out:
# Text(0.5, 1.0, 'Frquency of CollegeTier')

# %%
sns.countplot(df['CollegeCityTier'],palette="magma")
plt.title("Frequency of CollegeCityTier")
# Out:
# Text(0.5, 1.0, 'Frequency of CollegeCityTier')

# %%
score_columns = ["ComputerProgramming","ElectronicsAndSemicon","ComputerScience",
                "MechanicalEngg","ElectricalEngg","TelecomEngg","CivilEngg"]

# %%
numerical_columns = [col for col in numerical_columns if col not in score_columns]

# %%
for column in numerical_columns:
    sns.distplot(df[column])
    plt.title(f"Distribution of {column} Column")
    plt.show()

# %%
marker = dict(markerfacecolor='yellow',markeredgecolor='red',markersize=15,marker='o')

# %%
for column in numerical_columns:
    plt.figure(figsize=(14,7))
    sns.boxplot(df[column],color='blue',flierprops=marker)
    plt.show()

# %%
# Let's try to remove the Outliers in the numerical columns
def remove_outliers(data,columns):
    for column in columns:
        iqr = np.percentile(data[column],75) - np.percentile(data[column],25)
        lower_boundary = np.percentile(data[column],25) - (1.5 * iqr)
        upper_boundary = np.percentile(data[column],75) + (1.5 * iqr)
#         print(iqr,lower_boundary,upper_boundary)
        data = data[(data[column] >= lower_boundary) & (data[column] <= upper_boundary)]
    return data

# %%
x = df.copy()

# %%
new_df = remove_outliers(x,numerical_columns)
df = new_df.copy()

# %%
for column in numerical_columns:
    plt.figure(figsize=(14,7))
    sns.boxplot(df[column],color='red',flierprops=marker)
    plt.show()

# %%
df[numerical_columns]
# Out:
#       Salary  10percentage  12percentage  CollegeID  collegeGPA  \
# 0     420000         84.30         95.80       1141       78.00
# 1     500000         85.40         85.00       5807       70.06
# 2     325000         85.00         68.20         64       70.00
# 4     200000         78.00         76.80      11368       73.90
# 6     300000         86.08         67.50        314       72.98
# ...      ...           ...           ...        ...         ...
# 3993  280000         52.09         55.50       6268       61.50
# 3994  100000         90.00         93.00       4883       77.30
# 3995  320000         81.86         65.50       9786       70.00
# 3996  200000         78.72         69.88        979       70.42
# 3997  400000         70.60         68.00       6609       68.00
#
#       CollegeCityID  English  Logical  Quant    Domain  conscientiousness  \
# 0              1141      515      585    525  0.635979             0.9737
# 1              5807      695      610    780  0.960603            -0.7335
# 2                64      615      545    370  0.450877             0.2718
# 4             11368      545      625    465  0.124502            -0.8810
# 6               314      590      435    380  0.356536             1.7081
# ...             ...      ...      ...    ...       ...                ...
# 3993           6268      365      334    475  0.276047            -0.1082
# 3994           4883      415      410    535  0.881620            -0.3027
# 3995           9786      475      475    465  0.488348            -1.5765
# 3996            979      450      410    320  0.744758            -0.1590
# 3997           6609      565      515    464  0.600057            -1.1128
#
#       agreeableness  extraversion  nueroticism  openess_to_experience
# 0            0.8128        0.5269      1.35490                -0.4455
# 1            0.3789        1.2396     -0.10760                 0.8637
# 2            1.7109        0.1637     -0.86820                 0.6721
# 4           -0.2793       -1.0697      0.09163                -0.1295
# 6           -0.1054       -1.0379     -2.00920                -1.0872
# ...             ...           ...          ...                    ...
# 3993         0.3448        0.2366      0.64980                -0.9194
# 3994         0.8784        0.9322      0.77980                -0.0943
# 3995        -1.5273       -1.5051     -1.31840                -0.7615
# 3996         0.0459       -0.4511     -0.36120                -0.0943
# 3997        -0.2793       -0.6343      1.32553                -0.6035
#
# [3313 rows x 15 columns]

# %%
unique_values(df,score_columns)
# Out:
#                  Columns  No.of Unique Values
# 0    ComputerProgramming                   77
# 1  ElectronicsAndSemicon                   29
# 2        ComputerScience                   19
# 3         MechanicalEngg                   40
# 4         ElectricalEngg                   30
# 5            TelecomEngg                   26
# 6              CivilEngg                   16

# %%
# Checcking the Description of score_columns
df[score_columns].describe()
# Out:
#        ComputerProgramming  ElectronicsAndSemicon  ComputerScience  \
# count          3313.000000            3313.000000      3313.000000
# mean            362.365832              99.810444        95.697253
# std             199.561021             160.292736       179.320245
# min              -1.000000              -1.000000        -1.000000
# 25%             315.000000              -1.000000        -1.000000
# 50%             425.000000              -1.000000        -1.000000
# 75%             495.000000             260.000000        -1.000000
# max             840.000000             612.000000       715.000000
#
#        MechanicalEngg  ElectricalEngg  TelecomEngg    CivilEngg
# count     3313.000000     3313.000000  3313.000000  3313.000000
# mean        22.299427       17.549049    33.917597     1.925445
# std         96.971180       89.941584   107.507109    32.460049
# min         -1.000000       -1.000000    -1.000000    -1.000000
# 25%         -1.000000       -1.000000    -1.000000    -1.000000
# 50%         -1.000000       -1.000000    -1.000000    -1.000000
# 75%         -1.000000       -1.000000    -1.000000    -1.000000
# max        623.000000      676.000000   548.000000   516.000000

# %%
# Most of the features are in Normal and some of them are a bit Skewed

# %%
for column in numerical_columns:
    plt.figure(figsize=(15,8))
    sns.distplot(df[column],color='purple')
    rang = np.arange(df[column].min(),df[column].max(),0.1)
    plt.plot(rang,norm.pdf(rang,df[column].mean(),df[column].std()),color='black',ls="dashdot",label="Bell-Curve")
    plt.legend()
    plt.show()

# %%
for col in numerical_columns:
    qqplot(df[col],line='45',fit=True)
    plt.title(col)
    plt.show()

# %%
plt.figure(figsize=(15,15))
mask = np.triu(df[numerical_columns].corr())
sns.heatmap(df[numerical_columns].corr(),cmap='Wistia_r',mask=mask,annot=True)
plt.title("Correlation between all the Numerical Columns",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(df['Specialization'],hue='Degree',data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
top_20_specs = df['Specialization'].value_counts().head(20).index

# %%
ratio = []
for spec in top_20_specs:
    spec_df = df[df["Specialization"] == spec]
    ratio_dict = spec_df["Gender"].value_counts().to_dict()
    ratio.append(ratio_dict)

# %%
m_ratio = []
f_ratio = []
for i in ratio:
    m_ratio.append(i.get("m"))
    f_ratio.append(i.get("f"))

# %%
male_female_spec_ratio = pd.DataFrame({"Columns":top_20_specs,"Male":m_ratio,"Female":f_ratio})
male_female_spec_ratio["total"] = male_female_spec_ratio[['Male','Female']].sum(axis=1)

# %%
male_female_spec_ratio["Male_Perc"] = male_female_spec_ratio["Male"] / male_female_spec_ratio["total"] * 100

# %%
male_female_spec_ratio['Female_perc'] = male_female_spec_ratio['Female'] / male_female_spec_ratio['total'] * 100

# %%
male_female_spec_ratio["Difference"] =abs(male_female_spec_ratio['Male_Perc'] - male_female_spec_ratio['Female_perc'])

# %%
male_female_spec_ratio.fillna(0,inplace=True)

# %%
male_female_spec_ratio.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_78fe704e_42db_11ec_bf39_af3af67e8754row0_col1,#T_78fe704e_42db_11ec_bf39_af3af67e8754row0_col2,#T_78fe704e_42db_11ec_bf39_af3af67e8754row0_col3,#T_78fe704e_42db_11ec_bf39_af3af67e8754row6_col6,#T_78fe704e_42db_11ec_bf39_af3af67e8754row16_col4,#T_78fe704e_42db_11ec_bf39_af3af67e8754row18_col5,#T_78fe704e_42db_11ec_bf39_af3af67e8754row19_col4{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row0_col4{
#             background-color:  #f03d2d;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row0_col5,#T_78fe704e_42db_11ec_bf39_af3af67e8754row17_col6,#T_78fe704e_42db_11ec_bf39_af3af67e8754row18_col6{
#             background-color:  #fc9070;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row0_col6{
#             background-color:  #f5533b;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row1_col1,#T_78fe704e_42db_11ec_bf39_af3af67e8754row2_col2{
#             background-color:  #920a13;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row1_col2{
#             background-color:  #8a0812;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row1_col3{
#             background-color:  #900a12;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row1_col4{
#             background-color:  #f03f2e;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row1_col5{
#             background-color:  #fc8f6f;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row1_col6,#T_78fe704e_42db_11ec_bf39_af3af67e8754row3_col4{
#             background-color:  #f6563d;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row2_col1,#T_78fe704e_42db_11ec_bf39_af3af67e8754row11_col6{
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row2_col3{
#             background-color:  #b31218;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row2_col4{
#             background-color:  #f34c37;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row2_col5{
#             background-color:  #fc8464;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row2_col6,#T_78fe704e_42db_11ec_bf39_af3af67e8754row17_col5{
#             background-color:  #fb694a;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row3_col1{
#             background-color:  #dd2a25;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row3_col2{
#             background-color:  #ac1117;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row3_col3{
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row3_col5{
#             background-color:  #fb7b5b;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row3_col6,#T_78fe704e_42db_11ec_bf39_af3af67e8754row13_col4{
#             background-color:  #fb7656;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row4_col1,#T_78fe704e_42db_11ec_bf39_af3af67e8754row4_col3,#T_78fe704e_42db_11ec_bf39_af3af67e8754row5_col5,#T_78fe704e_42db_11ec_bf39_af3af67e8754row6_col1{
#             background-color:  #fcae92;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row4_col2{
#             background-color:  #fca98c;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row4_col4,#T_78fe704e_42db_11ec_bf39_af3af67e8754row12_col4{
#             background-color:  #f14331;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row4_col5,#T_78fe704e_42db_11ec_bf39_af3af67e8754row12_col5{
#             background-color:  #fc8b6b;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row4_col6,#T_78fe704e_42db_11ec_bf39_af3af67e8754row12_col6{
#             background-color:  #f75b40;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row5_col1{
#             background-color:  #fcbba1;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row5_col2{
#             background-color:  #fdd1be;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row5_col3{
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row5_col4{
#             background-color:  #d72322;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row5_col6{
#             background-color:  #da2723;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row6_col2{
#             background-color:  #ffece3;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row6_col3,#T_78fe704e_42db_11ec_bf39_af3af67e8754row11_col5{
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row6_col4{
#             background-color:  #940b13;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row6_col5{
#             background-color:  #fee6da;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row7_col1{
#             background-color:  #fedbcc;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row7_col2{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row7_col3{
#             background-color:  #fedccd;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row7_col4{
#             background-color:  #ef3c2c;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row7_col5,#T_78fe704e_42db_11ec_bf39_af3af67e8754row14_col5,#T_78fe704e_42db_11ec_bf39_af3af67e8754row15_col5{
#             background-color:  #fc9272;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row7_col6{
#             background-color:  #f5523a;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row8_col1{
#             background-color:  #fee5d8;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row8_col2{
#             background-color:  #ffebe2;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row8_col3{
#             background-color:  #fee7dc;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row8_col4{
#             background-color:  #cc191e;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row8_col5{
#             background-color:  #fcb89e;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row8_col6{
#             background-color:  #cb181d;
#             color:  #f1f1f1;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row9_col1,#T_78fe704e_42db_11ec_bf39_af3af67e8754row9_col3,#T_78fe704e_42db_11ec_bf39_af3af67e8754row11_col1,#T_78fe704e_42db_11ec_bf39_af3af67e8754row12_col2,#T_78fe704e_42db_11ec_bf39_af3af67e8754row13_col2{
#             background-color:  #fff0e9;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row9_col2{
#             background-color:  #ffeee6;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row9_col4,#T_78fe704e_42db_11ec_bf39_af3af67e8754row10_col4{
#             background-color:  #f96245;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row9_col5,#T_78fe704e_42db_11ec_bf39_af3af67e8754row10_col5{
#             background-color:  #fb7151;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row9_col6{
#             background-color:  #fc8666;
#             color:  #000000;
#         }#T_78fe704e_42db_11ec_bf39_af3af67e8754row10_col1,#T_78

# %%
male_female_spec_ratio.set_index("Columns",inplace=True)

# %%
plt.figure(figsize=(15,8))
male_female_spec_ratio[["Male","Female"]].plot(kind="bar",figsize=(20,10),fontsize=15)
plt.show()

# %%
df['Specialization'].value_counts().head(20)
# Out:
# electronics and communication engineering      703
# computer science & engineering                 644
# information technology                         583
# computer engineering                           511
# computer application                           209
# electronics and electrical engineering         165
# mechanical engineering                         163
# electronics & telecommunications               103
# electrical engineering                          64
# information science engineering                 25
# electronics & instrumentation eng               22
# electronics and instrumentation engineering     20
# civil engineering                               19
# instrumentation and control engineering         14
# electronics engineering                         12
# applied electronics and instrumentation          8
# industrial & production engineering              6
# computer science and technology                  6
# biotechnology                                    6
# automobile/automotive engineering                5
# Name: Specialization, dtype: int64

# %% [markdown]
# #### From the Above Observation we can see that "Male" candidates has Higher Specialization as compared to "Female".

# %%
# Transforming the numerical Columns.
scaler = StandardScaler()
scaled_cols = scaler.fit_transform(df[numerical_columns])

# %%
# Encoding Categorical Columns
categorical_columns
# Out:
# ['Designation',
#  'JobCity',
#  'Gender',
#  '10board',
#  '12board',
#  'Degree',
#  'Specialization',
#  'CollegeState']

# %%
categorical_discrete_columns
# Out:
# ['Gender', 'Degree']

# %%
df[categorical_columns].nunique()
# Out:
# Designation       389
# JobCity           286
# Gender              2
# 10board           245
# 12board           293
# Degree              4
# Specialization     31
# CollegeState       25
# dtype: int64

# %%
df['Gender'] = df['Gender'].map({"m":1,"f":2})

# %%
degree_labels = df['Degree'].value_counts().sort_values().index

# %%
degree_dict = {i:k for k,i in enumerate(degree_labels,0)}

# %%
df['Degree'] = df['Degree'].map(degree_dict)

# %%
# For the remaining columns we can make dummmy variables.
for col in ["Designation","JobCity","10board","12board","Specialization","CollegeState"]:
    dummy_df = pd.get_dummies(df[col],drop_first=True)
    print(col)
    df = pd.concat([df,dummy_df])
#     df.drop(col,axis=1,inplace=True)
# Out:
# Designation
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-174-c83132619fa4> in <module>
#       3     dummy_df = pd.get_dummies(df[col],drop_first=True)
#       4     print(col)
# ----> 5     df = pd.concat([df,dummy_df])
#       6 #     df.drop(col,axis=1,inplace=True)
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     360
#     361             # consolidate
# --> 362             obj._consolidate(inplace=True)
#     363             ndims.add(obj.ndim)
#     364
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in _consolidate(self, inplace)
#    5230         inplace = validate_bool_kwarg(inplace, "inplace")
#    5231         if inplace:
# -> 5232             self._consolidate_inplace()
#    5233         else:
#    5234             f = lambda: self._mgr.consolidate()
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5212             self._mgr = self._mgr.consolidate()
#    5213
# -> 5214         self._protect_consolidate(f)
#    5215
#    5216     def _consolidate(self, inplace: bool_t = False):
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5201         """
#    5202         blocks_before = len(self._mgr.blocks)
# -> 5203         result = f()
#    5204         if len(self._mgr.blocks) != blocks_before:
#    5205             self._clear_item_cache()
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in f()
#    5210
#    5211         def f():
# -> 5212             self._mgr = self._mgr.consolidate()
#    5213
#    5214         self._protect_consolidate(f)
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     972         bm = type(self)(self.blocks, self.axes)
#     973         bm._is_consolidated = False
# --> 974         bm._consolidate_inplace()
#     975         return bm
#     976
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     977     def _consolidate_inplace(self) -> None:
#     978         if not self.is_consolidated():
# --> 979             self.blocks = tuple(_consolidate(self.blocks))
#     980             self._is_consolidated = True
#     981             self._known_consolidated = True
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1897     new_blocks = []
#    1898     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1899         merged_blocks = _merge_blocks(
#    1900             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1901         )
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1920         # combination of those slices is a slice, too.
#    1921         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 1922         new_values = np.vstack([b.values for b in blocks])
#    1923
#    1924         argsort = np.argsort(new_mgr_locs)
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# c:\users\vinay naman\appdata\local\programs\python\python39\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 929. MiB for an array with shape (1148, 106016) and data type float64
